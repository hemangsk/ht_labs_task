# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
file = 'states.csv'

# %%
data = pd.read_csv(file)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4218 entries, 0 to 4217
# Data columns (total 8 columns):
# state                 4218 non-null object
# indicator_id          4218 non-null object
# indicator             4181 non-null object
# indicator_category    4181 non-null object
# urban                 4084 non-null object
# rural                 4103 non-null object
# total                 4218 non-null object
# total_2005-06         3305 non-null object
# dtypes: object(8)
# memory usage: 263.7+ KB

# %%
data = data.dropna(axis=0, how='any', subset=['urban', 'indicator_category', 'indicator_id', 'rural', 'total'])

# %%
data.head()
# Out:
#                          state indicator_id  \
# 0  Andaman and Nicobar Islands            1
# 1  Andaman and Nicobar Islands            2
# 2  Andaman and Nicobar Islands            3
# 3  Andaman and Nicobar Islands            4
# 4  Andaman and Nicobar Islands            5
#
#                                            indicator  \
# 0  Population (female) age 6 years and above who ...
# 1                  Population below age 15 years (%)
# 2  Sex ratio of the total population (females per...
# 3  Sex ratio at birth for children born in the la...
# 4  Children under age 5 years whose birth was reg...
#
#                   indicator_category urban rural total total_2005-06
# 0  Population and Household Profile   87.6  82.6  84.7           NaN
# 1  Population and Household Profile   23.4  24.3  23.9           NaN
# 2  Population and Household Profile    966   984   977           NaN
# 3  Population and Household Profile    708   978   859           NaN
# 4  Population and Household Profile   97.2  98.4  97.9           NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4048 entries, 0 to 4217
# Data columns (total 8 columns):
# state                 4048 non-null object
# indicator_id          4048 non-null object
# indicator             4048 non-null object
# indicator_category    4048 non-null object
# urban                 4048 non-null object
# rural                 4048 non-null object
# total                 4048 non-null object
# total_2005-06         3273 non-null object
# dtypes: object(8)
# memory usage: 284.6+ KB

# %%
data[data['indicator_id'] == '111']
# Out:
#                             state indicator_id                      indicator  \
# 109   Andaman and Nicobar Islands          111  Women who consume alcohol (%)
# 224                Andhra Pradesh          111  Women who consume alcohol (%)
# 337             Arunachal Pradesh          111  Women who consume alcohol (%)
# 451                         Assam          111  Women who consume alcohol (%)
# 565                         Bihar          111  Women who consume alcohol (%)
# 794                  Chhattisgarh          111  Women who consume alcohol (%)
# 907        Dadra and Nagar Haveli          111  Women who consume alcohol (%)
# 1021                Daman and Diu          111  Women who consume alcohol (%)
# 1135                        Delhi          111  Women who consume alcohol (%)
# 1249                          Goa          111  Women who consume alcohol (%)
# 1363                      Gujarat          111  Women who consume alcohol (%)
# 1478                      Haryana          111  Women who consume alcohol (%)
# 1592             Himachal Pradesh          111  Women who consume alcohol (%)
# 1705            Jammu and Kashmir          111  Women who consume alcohol (%)
# 1820                    Jharkhand          111  Women who consume alcohol (%)
# 1934                    Karnataka          111  Women who consume alcohol (%)
# 2048                       Kerala          111  Women who consume alcohol (%)
# 2161                  Lakshadweep          111  Women who consume alcohol (%)
# 2276               Madhya Pradesh          111  Women who consume alcohol (%)
# 2390                  Maharashtra          111  Women who consume alcohol (%)
# 2503                      Manipur          111  Women who consume alcohol (%)
# 2617                    Meghalaya          111  Women who consume alcohol (%)
# 2731                      Mizoram          111  Women who consume alcohol (%)
# 2845                     Nagaland          111  Women who consume alcohol (%)
# 2960                       Odisha          111  Women who consume alcohol (%)
# 3074                   Puducherry          111  Women who consume alcohol (%)
# 3188                       Punjab          111  Women who consume alcohol (%)
# 3302                    Rajasthan          111  Women who consume alcohol (%)
# 3416                       Sikkim          111  Women who consume alcohol (%)
# 3530                   Tamil Nadu          111  Women who consume alcohol (%)
# 3644                    Telangana          111  Women who consume alcohol (%)
# 3758                      Tripura          111  Women who consume alcohol (%)
# 3872                Uttar Pradesh          111  Women who consume alcohol (%)
# 3986                  Uttarakhand          111  Women who consume alcohol (%)
# 4099                  West Bengal          111  Women who consume alcohol (%)
# 4214                  West Bengal          111  Women who consume alcohol (%)
#
#                                      indicator_category urban rural total  \
# 109   Tobacco Use and Alcohol Consumption among Adul...   1.2   3.5   2.5
# 224   Tobacco Use and Alcohol Consumption among Adul...   0.1   0.6   0.4
# 337   Tobacco Use and Alcohol Consumption among Adul...  22.3  27.8  26.3
# 451   Tobacco Use and Alcohol Consumption among Adul...   2.9   7.7   6.9
# 565   Tobacco Use and Alcohol Consumption among Adul...   0.2   0.3   0.2
# 794   Tobacco Use and Alcohol Consumption among Adul...   1.4   6.2     5
# 907   Tobacco Use and Alcohol Consumption among Adul...     0     0     0
# 1021  Tobacco Use and Alcohol Consumption among Adul...   1.9   0.3   1.4
# 1135  Tobacco Use and Alcohol Consumption among Adul...   0.7     0   0.7
# 1249  Tobacco Use and Alcohol Consumption among Adul...   4.2   4.4   4.2
# 1363  Tobacco Use and Alcohol Consumption among Adul...   0.1   0.4   0.3
# 1478  Tobacco Use and Alcohol Consumption among Adul...   0.2   0.1   0.1
# 1592  Tobacco Use and Alcohol Consumption among Adul...   0.5   0.3   0.3
# 1705  Tobacco Use and Alcohol Consumption among Adul...   0.2   0.1   0.1
# 1820  Tobacco Use and Alcohol Consumption among Adul...   0.6   5.5   4.1
# 1934  Tobacco Use and Alcohol Consumption among Adul...   1.6   0.5     1
# 2048  Tobacco Use and Alcohol Consumption among Adul...   2.4   0.9   1.6
# 2161  Tobacco Use and Alcohol Consumption among Adul...     0     0     0
# 2276  Tobacco Use and Alcohol Consumption among Adul...   0.6   2.1   1.6
# 2390  Tobacco Use and Alcohol Consumption among Adul...   0.2   0.2   0.2
# 2503  Tobacco Use and Alcohol Consumption among Adul...   6.2   6.1   6.1
# 2617  Tobacco Use and Alcohol Consumption among Adul...   3.1   1.8   2.1
# 2731  Tobacco Use and Alcohol Consumption among Adul...   6.7   2.2     5
# 2845  Tobacco Use and Alcohol Consumption among Adul...   4.7   2.4   3.3
# 2960  Tobacco Use and Alcohol Consumption among Adul...   1.3   2.6   2.4
# 3074  Tobacco Use and Alcohol Consumption among Adul...   0.5   0.7   0.6
# 3188  Tobacco Use and Alcohol Consumption among Adul...   0.1     0   0.1
# 3302  Tobacco Use and Alcohol Consumption among Adul...   0.1   0.1   0.1
# 3416  Tobacco Use and Alcohol Consumption among Adul...  22.7  23.1    23
# 3530  Tobacco Use and Alcohol Consumption among Adul...   0.5   0.3   0.4
# 3644  Tobacco Use and Alcohol Consumption among Adul...   2.7  14.3   8.8
# 3758  Tobacco Use and Alcohol Consumption among Adul...   0.4   6.7   4.8
# 3872  Tobacco Use and Alcohol Consumption among Adul...   0.1   0.2   0.2
# 3986  Tobacco Use and Alcohol Consumption among Adul...   0.5   0.2   0.3
# 4099  Tobacco Use and Alcohol Consumption among Adul...   0.7   0.9   0.8
# 4214  Tobacco Use and Alcohol Consumption among Adul...   0.7   0.9   0.8
#
#      total_2005-06
# 109            NaN
# 224            NaN
# 337           33.6
# 451            7.5
# 565              1
# 794           11.4
# 907            NaN
# 1021           NaN
# 1135           0.4
# 1249           2.1
# 1363           0.8
# 1478           0.1
# 1592           0.1
# 1705             0
# 1820           9.9
# 1934           1.2
# 2048           0.7
# 2161           NaN
# 2276           2.1
# 2390           0.4
# 2503           1.9
# 2617           3.8
# 2731           0.7
# 2845           3.5
# 2960           7.3
# 3074           NaN
# 3188           0.2
# 3302           0.3
# 3416          19.2
# 3530           0.1
# 3644           NaN
# 3758           9.6
# 3872           0.3
# 3986           0.2
# 4099           1.7
# 4214           1.7

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4048 entries, 0 to 4217
# Data columns (total 8 columns):
# state                 4048 non-null object
# indicator_id          4048 non-null object
# indicator             4048 non-null object
# indicator_category    4048 non-null object
# urban                 4048 non-null object
# rural                 4048 non-null object
# total                 4048 non-null object
# total_2005-06         3273 non-null object
# dtypes: object(8)
# memory usage: 284.6+ KB
# None

# %%
data = data[data['indicator_id'] == '111']

# %%
data['urban'] = pd.to_numeric(data['urban'], errors='coerce')
data['rural'] = pd.to_numeric(data['rural'], errors='coerce')
data['total'] = pd.to_numeric(data['total'], errors='coerce')

data['indicator_id'] = pd.to_numeric(data['indicator_id'], errors='coerce')

# %%
data.head()
# Out:
#                            state  indicator_id                      indicator  \
# 109  Andaman and Nicobar Islands           111  Women who consume alcohol (%)
# 224               Andhra Pradesh           111  Women who consume alcohol (%)
# 337            Arunachal Pradesh           111  Women who consume alcohol (%)
# 451                        Assam           111  Women who consume alcohol (%)
# 565                        Bihar           111  Women who consume alcohol (%)
#
#                                     indicator_category  urban  rural  total  \
# 109  Tobacco Use and Alcohol Consumption among Adul...    1.2    3.5    2.5
# 224  Tobacco Use and Alcohol Consumption among Adul...    0.1    0.6    0.4
# 337  Tobacco Use and Alcohol Consumption among Adul...   22.3   27.8   26.3
# 451  Tobacco Use and Alcohol Consumption among Adul...    2.9    7.7    6.9
# 565  Tobacco Use and Alcohol Consumption among Adul...    0.2    0.3    0.2
#
#     total_2005-06
# 109           NaN
# 224           NaN
# 337          33.6
# 451           7.5
# 565             1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 109 to 4214
# Data columns (total 8 columns):
# state                 36 non-null object
# indicator_id          36 non-null int64
# indicator             36 non-null object
# indicator_category    36 non-null object
# urban                 36 non-null float64
# rural                 36 non-null float64
# total                 36 non-null float64
# total_2005-06         29 non-null object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
data = data.drop('indicator_id', axis=1)

# %%
data = data.drop('indicator_category', axis=1)

# %%
data.head()
# Out:
#                            state                      indicator  urban  rural  \
# 109  Andaman and Nicobar Islands  Women who consume alcohol (%)    1.2    3.5
# 224               Andhra Pradesh  Women who consume alcohol (%)    0.1    0.6
# 337            Arunachal Pradesh  Women who consume alcohol (%)   22.3   27.8
# 451                        Assam  Women who consume alcohol (%)    2.9    7.7
# 565                        Bihar  Women who consume alcohol (%)    0.2    0.3
#
#      total total_2005-06
# 109    2.5           NaN
# 224    0.4           NaN
# 337   26.3          33.6
# 451    6.9           7.5
# 565    0.2             1

# %%
data = data.drop('total_2005-06', axis=1)

# %%
data.head()
# Out:
#                            state                      indicator  urban  rural  \
# 109  Andaman and Nicobar Islands  Women who consume alcohol (%)    1.2    3.5
# 224               Andhra Pradesh  Women who consume alcohol (%)    0.1    0.6
# 337            Arunachal Pradesh  Women who consume alcohol (%)   22.3   27.8
# 451                        Assam  Women who consume alcohol (%)    2.9    7.7
# 565                        Bihar  Women who consume alcohol (%)    0.2    0.3
#
#      total
# 109    2.5
# 224    0.4
# 337   26.3
# 451    6.9
# 565    0.2

# %%
data = data.drop('indicator', axis=1)

# %%
data.head()
# Out:
#                            state  urban  rural  total
# 109  Andaman and Nicobar Islands    1.2    3.5    2.5
# 224               Andhra Pradesh    0.1    0.6    0.4
# 337            Arunachal Pradesh   22.3   27.8   26.3
# 451                        Assam    2.9    7.7    6.9
# 565                        Bihar    0.2    0.3    0.2

# %%
from collections import OrderedDict
result_color = OrderedDict([("urban","red"),("rural", "green"),("total","black"),])
data.to_csv('formatted_women.csv', index=False)

# %%
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
data_total = data[['state', 'total']].copy()
data_total = data_total.drop_duplicates(subset='state')
plotted = data_total.set_index('state').plot(kind='bar', figsize=(15,10))
plt.show()
fig = plotted.get_figure()
fig.savefig("swacw.png")
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
